# %%
import pandas as pd

# %%
import pandas as pd

dataframe = pd.read_csv(
    r"D:\Microsoft Machine Learning-20240818T000653Z-001\Microsoft Machine Learning\Course2_ Data science with python\Python, numpy, Data quality, Pandas\02-Pandas\iris.csv"
)

# %%
df.head(10)
# Out:
#    Id  sepallength  sepalwidth  petallength  petalwidth        class
# 0   1          5.1         3.5          1.4         0.2  Iris-setosa
# 1   2          4.9         3.0          1.4         0.2  Iris-setosa
# 2   3          4.7         3.2          1.3         0.2  Iris-setosa
# 3   4          4.6         3.1          1.5         0.2  Iris-setosa
# 4   5          5.0         3.6          1.4         0.2  Iris-setosa
# 5   6          5.4         3.9          1.7         0.4  Iris-setosa
# 6   7          4.6         3.4          1.4         0.3  Iris-setosa
# 7   8          5.0         3.4          1.5         0.2  Iris-setosa
# 8   9          4.4         2.9          1.4         0.2  Iris-setosa
# 9  10          4.9         3.1          1.5         0.1  Iris-setosa

# %%
Salaries=[2000,200,400,800,500,900,4358]
#s1= pd.Series(Salaries)
s1= pd.Series(Salaries,index=['a','b','c','d','e','f','g'])
s2= pd.Series(Salaries,index=['a','p','c','d','e','f','l'])
s1
s1['a':'b']
s1.iloc[[0, -1]]
# Out:
# a    2000
# g    4358
# dtype: int64

# %%
s1+s2
# Out:
# a    4000.0
# b       NaN
# c     800.0
# d    1600.0
# e    1000.0
# f    1800.0
# g       NaN
# l       NaN
# p       NaN
# dtype: float64

# %%
data = [
    ["Ali", 23, "Cairo"],
    ["Mona", 25, "Alex"],
    ["Sara", 22, "Giza"]
]

df = pd.DataFrame(data, columns=["Name", "Age", "City"])
df
# Out:
#    Name  Age   City
# 0   Ali   23  Cairo
# 1  Mona   25   Alex
# 2  Sara   22   Giza

# %%
dataa={
    'name':['ali','adam','mah'],
    'age':[12,52,78],
    'grade':[25,86,89]}
df2=pd.DataFrame(dataa,index=[1,2,3])
df2
# Out:
#    name  age  grade
# 1   ali   12     25
# 2  adam   52     86
# 3   mah   78     89

# %%
dataframe.head(5)
# Out:
#    Id  sepallength  sepalwidth  petallength  petalwidth        class
# 0   1          5.1         3.5          1.4         0.2  Iris-setosa
# 1   2          4.9         3.0          1.4         0.2  Iris-setosa
# 2   3          4.7         3.2          1.3         0.2  Iris-setosa
# 3   4          4.6         3.1          1.5         0.2  Iris-setosa
# 4   5          5.0         3.6          1.4         0.2  Iris-setosa

# %%
dataframe.loc[2,'sepallength']
dataframe.loc[2]
dataframe.loc[:,'sepallength']
dataframe.loc[[2,4,5],['sepallength','class']]
dataframe.iloc[2,2]    
dataframe.iloc[1:3,0:2]    
dataframe.iloc[[2,3],[2,3]]
# Out:
#    sepalwidth  petallength
# 2         3.2          1.3
# 3         3.1          1.5

# %%
dataframe[dataframe["class"] == "Iris-setosa"]
# Out:
#      Id  sepallength  sepalwidth  petallength  petalwidth        class
# 0     1          5.1         3.5          1.4         0.2  Iris-setosa
# 1     2          4.9         3.0          1.4         0.2  Iris-setosa
# 2     3          4.7         3.2          1.3         0.2  Iris-setosa
# 3     4          4.6         3.1          1.5         0.2  Iris-setosa
# 4     5          5.0         3.6          1.4         0.2  Iris-setosa
# 5     6          5.4         3.9          1.7         0.4  Iris-setosa
# 6     7          4.6         3.4          1.4         0.3  Iris-setosa
# 7     8          5.0         3.4          1.5         0.2  Iris-setosa
# 8     9          4.4         2.9          1.4         0.2  Iris-setosa
# 9    10          4.9         3.1          1.5         0.1  Iris-setosa
# 10   11          5.4         3.7          1.5         0.2  Iris-setosa
# 11   12          4.8         3.4          1.6         0.2  Iris-setosa
# ...

# %%
dataframe[dataframe['class'].str.contains("setosa")]
# Out:
#      Id  sepallength  sepalwidth  petallength  petalwidth        class
# 0     1          5.1         3.5          1.4         0.2  Iris-setosa
# 1     2          4.9         3.0          1.4         0.2  Iris-setosa
# 2     3          4.7         3.2          1.3         0.2  Iris-setosa
# 3     4          4.6         3.1          1.5         0.2  Iris-setosa
# 4     5          5.0         3.6          1.4         0.2  Iris-setosa
# 5     6          5.4         3.9          1.7         0.4  Iris-setosa
# 6     7          4.6         3.4          1.4         0.3  Iris-setosa
# 7     8          5.0         3.4          1.5         0.2  Iris-setosa
# 8     9          4.4         2.9          1.4         0.2  Iris-setosa
# 9    10          4.9         3.1          1.5         0.1  Iris-setosa
# 10   11          5.4         3.7          1.5         0.2  Iris-setosa
# 11   12          4.8         3.4          1.6         0.2  Iris-setosa
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id           153 non-null    int64
#  1   sepallength  152 non-null    float64
#  2   sepalwidth   153 non-null    float64
#  3   petallength  151 non-null    float64
#  4   petalwidth   153 non-null    float64
#  5   class        153 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.3+ KB

# %%
dataframe.describe()
# Out:
#                Id  sepallength  sepalwidth  petallength  petalwidth
# count  153.000000   152.000000  153.000000   151.000000  153.000000
# mean    74.058824     5.819079    3.057516     3.688742    1.179085
# std     44.213036     0.830282    0.430986     1.778709    0.768256
# min      1.000000     4.300000    2.000000     1.000000    0.100000
# 25%     36.000000     5.100000    2.800000     1.500000    0.300000
# 50%     74.000000     5.750000    3.000000     4.200000    1.300000
# 75%    112.000000     6.400000    3.300000     5.100000    1.800000
# max    150.000000     7.900000    4.400000     6.900000    2.500000

# %%
dataframe.drop([2,3])
# Out:
#       Id  sepallength  sepalwidth  petallength  petalwidth           class
# 0      1          5.1         3.5          1.4         0.2     Iris-setosa
# 1      2          4.9         3.0          1.4         0.2     Iris-setosa
# 4      5          5.0         3.6          1.4         0.2     Iris-setosa
# 5      6          5.4         3.9          1.7         0.4     Iris-setosa
# 6      7          4.6         3.4          1.4         0.3     Iris-setosa
# ..   ...          ...         ...          ...         ...             ...
# 148  149          6.2         3.4          NaN         2.3  Iris-virginica
# 149  150          5.9         3.0          5.1         1.8  Iris-virginica
# 150    1          5.1         3.5          1.4         0.2     Iris-setosa
# 151    2          4.9         3.0          1.4         0.2     Iris-setosa
# 152    3          4.7         3.2          1.3         0.2     Iris-setosa
#
# [151 rows x 6 columns]

# %%
dataframe
# Out:
#       Id  sepallength  sepalwidth  petallength  petalwidth           class
# 0      1          5.1         3.5          1.4         0.2     Iris-setosa
# 1      2          4.9         3.0          1.4         0.2     Iris-setosa
# 2      3          4.7         3.2          1.3         0.2     Iris-setosa
# 3      4          4.6         3.1          1.5         0.2     Iris-setosa
# 4      5          5.0         3.6          1.4         0.2     Iris-setosa
# ..   ...          ...         ...          ...         ...             ...
# 148  149          6.2         3.4          NaN         2.3  Iris-virginica
# 149  150          5.9         3.0          5.1         1.8  Iris-virginica
# 150    1          5.1         3.5          1.4         0.2     Iris-setosa
# 151    2          4.9         3.0          1.4         0.2     Iris-setosa
# 152    3          4.7         3.2          1.3         0.2     Iris-setosa
#
# [153 rows x 6 columns]

# %%
dataframe.dropna(how='all')
# Out:
#       Id  sepallength  sepalwidth  petallength  petalwidth           class
# 0      1          5.1         3.5          1.4         0.2     Iris-setosa
# 1      2          4.9         3.0          1.4         0.2     Iris-setosa
# 2      3          4.7         3.2          1.3         0.2     Iris-setosa
# 3      4          4.6         3.1          1.5         0.2     Iris-setosa
# 4      5          5.0         3.6          1.4         0.2     Iris-setosa
# ..   ...          ...         ...          ...         ...             ...
# 148  149          6.2         3.4          NaN         2.3  Iris-virginica
# 149  150          5.9         3.0          5.1         1.8  Iris-virginica
# 150    1          5.1         3.5          1.4         0.2     Iris-setosa
# 151    2          4.9         3.0          1.4         0.2     Iris-setosa
# 152    3          4.7         3.2          1.3         0.2     Iris-setosa
#
# [153 rows x 6 columns]

# %%
dataframe.dropna(how='any')
# Out:
#       Id  sepallength  sepalwidth  petallength  petalwidth           class
# 0      1          5.1         3.5          1.4         0.2     Iris-setosa
# 1      2          4.9         3.0          1.4         0.2     Iris-setosa
# 2      3          4.7         3.2          1.3         0.2     Iris-setosa
# 3      4          4.6         3.1          1.5         0.2     Iris-setosa
# 4      5          5.0         3.6          1.4         0.2     Iris-setosa
# ..   ...          ...         ...          ...         ...             ...
# 147  148          6.5         3.0          5.2         2.0  Iris-virginica
# 149  150          5.9         3.0          5.1         1.8  Iris-virginica
# 150    1          5.1         3.5          1.4         0.2     Iris-setosa
# 151    2          4.9         3.0          1.4         0.2     Iris-setosa
# 152    3          4.7         3.2          1.3         0.2     Iris-setosa
#
# [150 rows x 6 columns]

# %%
dataframe.dropna(subset=['petallength'])# name of column u want to drop nan values form it
# Out:
#       Id  sepallength  sepalwidth  petallength  petalwidth           class
# 0      1          5.1         3.5          1.4         0.2     Iris-setosa
# 1      2          4.9         3.0          1.4         0.2     Iris-setosa
# 2      3          4.7         3.2          1.3         0.2     Iris-setosa
# 3      4          4.6         3.1          1.5         0.2     Iris-setosa
# 4      5          5.0         3.6          1.4         0.2     Iris-setosa
# ..   ...          ...         ...          ...         ...             ...
# 147  148          6.5         3.0          5.2         2.0  Iris-virginica
# 149  150          5.9         3.0          5.1         1.8  Iris-virginica
# 150    1          5.1         3.5          1.4         0.2     Iris-setosa
# 151    2          4.9         3.0          1.4         0.2     Iris-setosa
# 152    3          4.7         3.2          1.3         0.2     Iris-setosa
#
# [151 rows x 6 columns]

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id           153 non-null    int64
#  1   sepallength  152 non-null    float64
#  2   sepalwidth   153 non-null    float64
#  3   petallength  151 non-null    float64
#  4   petalwidth   153 non-null    float64
#  5   class        153 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.3+ KB

# %%
dataframe['petallength'].fillna(method='ffill',inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_24368\2245363327.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataframe['petallength'].fillna(method='ffill',inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_24368\2245363327.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataframe['petallength'].fillna(method='ffill',inplace=True)

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id           153 non-null    int64
#  1   sepallength  152 non-null    float64
#  2   sepalwidth   153 non-null    float64
#  3   petallength  153 non-null    float64
#  4   petalwidth   153 non-null    float64
#  5   class        153 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.3+ KB

# %%
dataframe['sepallength'].fillna(method='bfill',inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_24368\3422783775.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataframe['sepallength'].fillna(method='bfill',inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_24368\3422783775.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataframe['sepallength'].fillna(method='bfill',inplace=True)

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id           153 non-null    int64
#  1   sepallength  153 non-null    float64
#  2   sepalwidth   153 non-null    float64
#  3   petallength  153 non-null    float64
#  4   petalwidth   153 non-null    float64
#  5   class        153 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.3+ KB

# %%
dataframe.drop_duplicates(inplace=True)

# %%
dataframe.set_index('Id',inplace=True)

# %%
dataframe
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# Id
# 1            5.1         3.5          1.4         0.2     Iris-setosa
# 2            4.9         3.0          1.4         0.2     Iris-setosa
# 3            4.7         3.2          1.3         0.2     Iris-setosa
# 4            4.6         3.1          1.5         0.2     Iris-setosa
# 5            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 146          6.7         3.0          5.2         2.3  Iris-virginica
# 147          6.3         2.5          5.0         1.9  Iris-virginica
# 148          6.5         3.0          5.2         2.0  Iris-virginica
# 149          6.2         3.4          5.2         2.3  Iris-virginica
# 150          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
dataframe.reset_index()
# Out:
#      index   Id  sepallength  sepalwidth  petallength  petalwidth  \
# 0        0    1          5.1         3.5          1.4         0.2
# 1        1    2          4.9         3.0          1.4         0.2
# 2        2    3          4.7         3.2          1.3         0.2
# 3        3    4          4.6         3.1          1.5         0.2
# 4        4    5          5.0         3.6          1.4         0.2
# ..     ...  ...          ...         ...          ...         ...
# 145    145  146          6.7         3.0          5.2         2.3
# 146    146  147          6.3         2.5          5.0         1.9
# 147    147  148          6.5         3.0          5.2         2.0
# 148    148  149          6.2         3.4          5.2         2.3
# 149    149  150          5.9         3.0          5.1         1.8
#
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# ...

# %%
dataframe.drop(columns=['index','level_0'],inplace=True)

# %%
dataframe
# Out:
#       Id  sepallength  sepalwidth  petallength  petalwidth           class
# 0      1          5.1         3.5          1.4         0.2     Iris-setosa
# 1      2          4.9         3.0          1.4         0.2     Iris-setosa
# 2      3          4.7         3.2          1.3         0.2     Iris-setosa
# 3      4          4.6         3.1          1.5         0.2     Iris-setosa
# 4      5          5.0         3.6          1.4         0.2     Iris-setosa
# ..   ...          ...         ...          ...         ...             ...
# 145  146          6.7         3.0          5.2         2.3  Iris-virginica
# 146  147          6.3         2.5          5.0         1.9  Iris-virginica
# 147  148          6.5         3.0          5.2         2.0  Iris-virginica
# 148  149          6.2         3.4          5.2         2.3  Iris-virginica
# 149  150          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
dataframe.groupby("class")["sepallength"].mean()
# Out:
# class
# Iris-setosa        5.006
# Iris-versicolor    5.936
# Iris-virginica     6.598
# Name: sepallength, dtype: float64

# %%
dataframe.groupby(["class", "sepalwidth"]).mean()
# Out:
#                                     Id  sepallength  petallength  petalwidth
# class           sepalwidth
# Iris-setosa     2.3          42.000000     4.500000     1.300000    0.300000
#                 2.9           9.000000     4.400000     1.400000    0.200000
#                 3.0          23.333333     4.700000     1.366667    0.183333
#                 3.1          23.600000     4.820000     1.520000    0.140000
#                 3.2          32.000000     4.680000     1.360000    0.200000
#                 3.3          37.000000     5.050000     1.550000    0.350000
#                 3.4          22.333333     5.033333     1.566667    0.255556
#                 3.5          28.166667     5.150000     1.416667    0.300000
#                 3.6          14.000000     4.800000     1.200000    0.200000
#                 3.7          27.333333     5.266667     1.500000    0.266667
#                 3.8          32.750000     5.250000     1.675000    0.300000
# ...

# %%
dataframe
# Out:
#       Id  sepallength  sepalwidth  petallength  petalwidth           class
# 0      1          5.1         3.5          1.4         0.2     Iris-setosa
# 1      2          4.9         3.0          1.4         0.2     Iris-setosa
# 2      3          4.7         3.2          1.3         0.2     Iris-setosa
# 3      4          4.6         3.1          1.5         0.2     Iris-setosa
# 4      5          5.0         3.6          1.4         0.2     Iris-setosa
# ..   ...          ...         ...          ...         ...             ...
# 145  146          6.7         3.0          5.2         2.3  Iris-virginica
# 146  147          6.3         2.5          5.0         1.9  Iris-virginica
# 147  148          6.5         3.0          5.2         2.0  Iris-virginica
# 148  149          6.2         3.4          5.2         2.3  Iris-virginica
# 149  150          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
dataframe.sort_values(by=["sepallength","petallength"])
# Out:
#       Id  sepallength  sepalwidth  petallength  petalwidth           class
# 13    14          4.3         3.0          1.1         0.1     Iris-setosa
# 38    39          4.4         3.0          1.3         0.2     Iris-setosa
# 42    43          4.4         3.2          1.3         0.2     Iris-setosa
# 8      9          4.4         2.9          1.4         0.2     Iris-setosa
# 41    42          4.5         2.3          1.3         0.3     Iris-setosa
# ..   ...          ...         ...          ...         ...             ...
# 135  136          7.7         3.0          6.1         2.3  Iris-virginica
# 117  118          7.7         3.8          6.7         2.2  Iris-virginica
# 122  123          7.7         2.8          6.7         2.0  Iris-virginica
# 118  119          7.7         2.6          6.9         2.3  Iris-virginica
# 131  132          7.9         3.8          6.4         2.0  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df2=pd.read_excel(r"D:\Microsoft Machine Learning-20240818T000653Z-001\Microsoft Machine Learning\Course2_ Data science with python\Python, numpy, Data quality, Pandas\02-Pandas\Excel_Sample.xlsx")

# %%
df2.columns=['Id','b','c','d','g']

# %%
df2
# Out:
#    Id   b   c   d   g
# 0   0   0   1   2   3
# 1   1   4   5   6   7
# 2   2   8   9  10  11
# 3   3  12  13  14  15

# %%
pd.concat([dataframe,df2],axis=1)
# Out:
#       Id  sepallength  sepalwidth  petallength  petalwidth           class  \
# 0      1          5.1         3.5          1.4         0.2     Iris-setosa
# 1      2          4.9         3.0          1.4         0.2     Iris-setosa
# 2      3          4.7         3.2          1.3         0.2     Iris-setosa
# 3      4          4.6         3.1          1.5         0.2     Iris-setosa
# 4      5          5.0         3.6          1.4         0.2     Iris-setosa
# ..   ...          ...         ...          ...         ...             ...
# 145  146          6.7         3.0          5.2         2.3  Iris-virginica
# 146  147          6.3         2.5          5.0         1.9  Iris-virginica
# 147  148          6.5         3.0          5.2         2.0  Iris-virginica
# 148  149          6.2         3.4          5.2         2.3  Iris-virginica
# 149  150          5.9         3.0          5.1         1.8  Iris-virginica
#
#       Id     b     c     d     g
# 0    0.0   0.0   1.0   2.0   3.0
# ...

# %%
dataframe.merge(df2,on="Id",how='inner')
# Out:
#    Id  sepallength  sepalwidth  petallength  petalwidth        class   b   c  \
# 0   1          5.1         3.5          1.4         0.2  Iris-setosa   4   5
# 1   2          4.9         3.0          1.4         0.2  Iris-setosa   8   9
# 2   3          4.7         3.2          1.3         0.2  Iris-setosa  12  13
#
#     d   g
# 0   6   7
# 1  10  11
# 2  14  15

# %%
dataframe.merge(df2,on="Id",how='left')
# Out:
#       Id  sepallength  sepalwidth  petallength  petalwidth           class  \
# 0      1          5.1         3.5          1.4         0.2     Iris-setosa
# 1      2          4.9         3.0          1.4         0.2     Iris-setosa
# 2      3          4.7         3.2          1.3         0.2     Iris-setosa
# 3      4          4.6         3.1          1.5         0.2     Iris-setosa
# 4      5          5.0         3.6          1.4         0.2     Iris-setosa
# ..   ...          ...         ...          ...         ...             ...
# 145  146          6.7         3.0          5.2         2.3  Iris-virginica
# 146  147          6.3         2.5          5.0         1.9  Iris-virginica
# 147  148          6.5         3.0          5.2         2.0  Iris-virginica
# 148  149          6.2         3.4          5.2         2.3  Iris-virginica
# 149  150          5.9         3.0          5.1         1.8  Iris-virginica
#
#         b     c     d     g
# 0     4.0   5.0   6.0   7.0
# ...

# %%
dataframe.merge(df2,on="Id",how='right')
# Out:
#    Id  sepallength  sepalwidth  petallength  petalwidth        class   b   c  \
# 0   0          NaN         NaN          NaN         NaN          NaN   0   1
# 1   1          5.1         3.5          1.4         0.2  Iris-setosa   4   5
# 2   2          4.9         3.0          1.4         0.2  Iris-setosa   8   9
# 3   3          4.7         3.2          1.3         0.2  Iris-setosa  12  13
#
#     d   g
# 0   2   3
# 1   6   7
# 2  10  11
# 3  14  15

# %%
dataframe.dtypes
# Out:
# Id               int64
# sepallength    float64
# sepalwidth     float64
# petallength    float64
# petalwidth     float64
# class           object
# dtype: object

# %%
dataframe['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
dataframe['class'].nunique()
# Out:
# 3

# %%
dataframe['class'].value_counts()
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64
